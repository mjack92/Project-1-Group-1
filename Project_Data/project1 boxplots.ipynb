# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime

# %%
# Load in csv
top50_df = pd.read_csv("top_50_combined_features.csv")
top50_df.head()
# Out:
#                               Track URI          Track Name  \
# 0  spotify:track:7K3BhSpAxZBznislvUMVtn          Last Night
# 1  spotify:track:1Qrg8KqiBpW07V7PNxwwwL           Kill Bill
# 2  spotify:track:6AQbmUe0Qwf5PZnt4HmTXv  Boy's a liar Pt. 2
# 3  spotify:track:3dnP0JxCgygwQH9Gm7q7nb     Ella Baila Sola
# 4  spotify:track:4DHcnVTT87F0zZhRPYmZ3B             Flowers
#
#                                        Artist URI(s)  \
# 0              spotify:artist:4oUHIQIBe0LHzYfvXNW4QM
# 1              spotify:artist:7tYKF4w9nC0nq9CsPZTHyP
# 2  spotify:artist:78rUTD7y6Cy67W1RVzYs7t, spotify...
# 3  spotify:artist:0XeEobZplHxzM9QzFQWLiR, spotify...
# 4              spotify:artist:5YGY8feqx7naU7z4HrwZM6
#
#                Artist Name(s)                             Album URI  \
# 0               Morgan Wallen  spotify:album:6i7mF7whyRJuLJ4ogbH2wh
# 1                         SZA  spotify:album:1nrVofqDRs7cpWXJ49qTnP
# 2   PinkPantheress, Ice Spice  spotify:album:6cVfHBcp3AdpYY0bBglkLN
# 3  Eslabon Armado, Peso Pluma  spotify:album:3Mm1P5CEEAiuJqBclr2EyU
# 4                 Miley Cyrus  spotify:album:0HiZ8fNXwJOQcrf5iflrdz
#
#                 Album Name                                Album Artist URI(s)  \
# 0      One Thing At A Time              spotify:artist:4oUHIQIBe0LHzYfvXNW4QM
# 1                      SOS              spotify:artist:7tYKF4w9nC0nq9CsPZTHyP
# 2       Boy's a liar Pt. 2  spotify:artist:78rUTD7y6Cy67W1RVzYs7t, spotify...
# 3          Ella Baila Sola  spotify:artist:0XeEobZplHxzM9QzFQWLiR, spotify...
# 4  Endless Summer Vacation              spotify:artist:5YGY8feqx7naU7z4HrwZM6
#
#          Album Artist Name(s) Album Release Date  \
# 0               Morgan Wallen           3/3/2023
# 1                         SZA          12/8/2022
# 2   PinkPantheress, Ice Spice           2/3/2023
# 3  Eslabon Armado, Peso Pluma          3/16/2023
# 4                 Miley Cyrus          3/10/2023
#
#                                      Album Image URL  ...  Loudness  Mode  \
# 0  https://i.scdn.co/image/ab67616d0000b273705079...  ...    -5.456     1
# 1  https://i.scdn.co/image/ab67616d0000b2730c471c...  ...    -5.747     1
# 2  https://i.scdn.co/image/ab67616d0000b27342c5ba...  ...    -8.254     1
# 3  https://i.scdn.co/image/ab67616d0000b2732071a0...  ...    -5.176     0
# 4  https://i.scdn.co/image/ab67616d0000b27358039b...  ...    -4.325     1
#
#    Speechiness Acousticness  Instrumentalness  Liveness Valence    Tempo  \
# 0       0.0389       0.4670          0.000000    0.1420   0.478  203.759
# 1       0.0391       0.0521          0.144000    0.1610   0.418   88.980
# 2       0.0500       0.2520          0.000128    0.2480   0.857  132.962
# 3       0.0332       0.4830          0.000019    0.0837   0.834  147.989
# 4       0.0668       0.0632          0.000005    0.0322   0.646  117.999
#
#   Time Signature  Country
# 0              4       US
# 1              4       US
# 2              4       US
# 3              3       US
# 4              4       US
#
# [5 rows x 32 columns]

# %%
# Drop extra columns

top50_clean = top50_df.drop(columns=["Track URI", "Artist URI(s)", "Album URI", "Album Artist URI(s)", 
                       "Album Artist Name(s)", "Album Image URL", "Disc Number", 
                       "Track Number", "Track Preview URL", "ISRC", "Added By", "Added At"])

# %%
# top50_clean.head()
top50_clean.tail()
# Out:
#        Track Name   Artist Name(s)                   Album Name  \
# 245        Cookie         NewJeans  NewJeans 1st EP 'New Jeans'
# 246         Lemon    Kenshi Yonezu                  STRAY SHEEP
# 247  Lovely Touch  Lim Young Woong                      IM HERO
# 248     As It Was     Harry Styles                Harry's House
# 249        ベテルギウス            Yuuri                            壱
#
#     Album Release Date  Track Duration (ms)  Explicit  Popularity  \
# 245           8/1/2022               235562     False          82
# 246           8/5/2020               255826     False          71
# 247           5/2/2022               195173     False          54
# 248          5/20/2022               167303     False          92
# 249          1/12/2022               230600     False          74
#
#      Danceability  Energy  Key  Loudness  Mode  Speechiness  Acousticness  \
# 245         0.847   0.638    0    -3.764     1       0.0575        0.0596
# 246         0.525   0.646   11    -4.963     1       0.0268        0.3040
# 247         0.372   0.551    6    -3.508     1       0.0324        0.5360
# 248         0.520   0.731    6    -5.338     0       0.0557        0.3420
# 249         0.367   0.671    5    -4.604     1       0.0478        0.2220
#
#      Instrumentalness  Liveness  Valence    Tempo  Time Signature Country
# 245           0.00000    0.0894    0.661  156.935               4      SK
# 246           0.00000    0.2970    0.373   86.957               4      SK
# 247           0.00000    0.2260    0.444  105.104               3      SK
# 248           0.00101    0.3110    0.662  173.930               4      SK
# 249           0.00000    0.4940    0.691  179.833               4      SK

# %%
# Split up data into groups based upon "Country"
country_groups = top50_clean.groupby("Country")

# Find average Danceability score
danceability_avg = country_groups["Danceability"].mean()

# Chart danceability by country
danceability_chart = danceability_avg.plot(kind="bar", title="Average Danceability by Country", color=["steelblue", "steelblue", "steelblue", "steelblue", "orange"])
danceability_chart.set_xlabel("Country")
danceability_chart.set_ylabel("Average Danceability")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Split up data into groups based upon "Country"
country_groups = top50_clean.groupby("Country")

# Find average tempo score
tempo_avg = country_groups["Tempo"].mean()

# Chart danceability by country
tempo_chart = tempo_avg.plot(kind="bar", title="Average Tempo by Country", color=["steelblue", "steelblue", "steelblue", "steelblue", "orange"])
tempo_chart.set_xlabel("Country")
tempo_chart.set_ylabel("Average Tempo")

plt.show()
plt.tight_layout()

# %%
# Split up data into groups based upon "Country"
country_groups = top50_clean.groupby("Country")

# Find average loudness score
loudness_avg = country_groups["Loudness"].mean()

# Chart danceability by country
loudness_chart = loudness_avg.plot(kind="bar", title="Average Loudness by Country", color=["steelblue", "steelblue", "steelblue", "steelblue", "orange"])
loudness_chart.set_xlabel("Country")
loudness_chart.set_ylabel("Average Loudness")

plt.show()
plt.tight_layout()

# %%
# Scatter plot
# Create scatter plot that compares popularity to danceability
country_groups = top50_clean.groupby("Country")
top50_clean.plot(kind="scatter", x="Danceability", y="Tempo", s="Tempo",
                grid=True, figsize=(8,8), title="Danceability vs. Tempo", 
                color="m", marker="*", alpha=0.5)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# Scatter plot
# Create scatter plot that compares popularity to energy
country_groups = top50_clean.groupby("Country")
top50_clean.plot(kind="scatter", x="Danceability", y="Energy", s=20,
                grid=True, figsize=(8,8), title="Danceability vs. Energy", 
                color="b", marker="X", alpha=0.5)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# Scatter plot
# Create scatter plot that compares popularity to energy
country_groups = top50_clean.groupby("Country")
top50_clean.plot(kind="scatter", x="Danceability", y="Liveness", s=20,
                grid=True, figsize=(8,8), title="Danceability vs. Liveness", 
                color="lime", marker="D", alpha=0.5)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
top50_df.boxplot('Danceability', by = 'Country',figsize=(6,5))
# Out:
# <img src="data:image/png;base64,..." width="600">
# <AxesSubplot:title={'center':'Danceability'}, xlabel='Country'>

# %%
top50_df.boxplot('Energy', by='Country', figsize=(6,5))
# Out:
# <img src="data:image/png;base64,..." width="600">
# <AxesSubplot:title={'center':'Energy'}, xlabel='Country'>

# %%
top50_df.boxplot('Loudness', by='Country', figsize=(6,5))
# Out:
# <img src="data:image/png;base64,..." width="600">
# <AxesSubplot:title={'center':'Loudness'}, xlabel='Country'>

# %%
top50_df.boxplot('Tempo', by='Country', figsize=(6,5))
# Out:
# <img src="data:image/png;base64,..." width="600">
# <AxesSubplot:title={'center':'Tempo'}, xlabel='Country'>

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
mod = ols('Tempo - Country', top50_df = top50_df).fit()
aov_table = sm.stats.anovalm(mod, type=4)
print(aov_table)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5060\395019469.py in <module>
# ----> 1 mod = ols('Tempo - Country', top50_df = top50_df).fit()
#       2 aov_table = sm.stats.anovalm(mod, type=4)
#       3 print(aov_table)
#
# TypeError: from_formula() missing 1 required positional argument: 'data'
